# %%
import numpy as np
import matplotlib.pyplot as plt


#dp, media, maior, menor
ag_b = [0.03186,0.04973,0.13857, 0.00000] 

ag_r = [0.05596,0.08610,0.19174, 0.00740]

ee = [0.04662, 0.04176, 0.25104, 0.00000]
#print (data.type())
fig1, ax1 = plt.subplots()
ax1.set_title('Comparação dos métodos')
ax1.set_xticklabels(['AG Binário', 'AG Real', 'Estratégia Evolutiva'])

ax1.boxplot([ag_b,ag_r,ee])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff4d176ef60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff4d17e2da0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff4d1775dd8>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff4d1775a58>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff4d176ecf8>,
# ...
#   <matplotlib.lines.Line2D at 0x7ff4d1799198>]}
